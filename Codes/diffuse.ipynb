# %%
from PIL import Image
import numpy as np

# %%
img = Image.open("taj.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=512x512>

# %%
noise = 256*np.random.rand(*img.size,3)
print(noise.shape)
# Out:
# (512, 512, 3)

# %%
noise = 256*np.random.rand(*img.size,3)
noisy_image = ((img + noise)/2).astype(np.uint8)
Image.fromarray(noisy_image)
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
Image.fromarray(noise.astype(np.uint8))
# Out:
# <PIL.Image.Image image mode=RGB size=512x512>

# %%
# input and output to Unet Model
Image.fromarray(noisy_image).save("noisy_image.png")
Image.fromarray(noise.astype(np.uint8)).save("noise.png")
